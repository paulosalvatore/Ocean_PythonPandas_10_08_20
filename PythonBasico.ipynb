# %%
numero = 5

# %%
numero = numero + 2
print(numero)
# Out:
# 7

# %%
numero = numero + 1

# %%
numero = 2 * 5
print(numero)
# Out:
# 10

# %%
numero = 1
texto = "Paulo"
vivo = True
morto = False
numero_decimal = 5.5
lista = [1, 2, 3, 4]
tupla = (1, 2, 3, 4)
dicionario = {'Estado': 'Bahia'}

print(type(numero))
print(type(texto))
print(type(vivo))
print(type(morto))
print(type(numero_decimal))
print(type(lista))
print(type(tupla))
print(type(dicionario))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'bool'>
# <class 'bool'>
# <class 'float'>
# <class 'list'>
# <class 'tuple'>
# <class 'dict'>

# %%
linha1 = [1, 2, 3]
linha2 = [4, 5, 6]
matriz = [linha1, linha2]

# %%
lista = [4, 9, 3]

print(lista)

lista[0] = 12

primeiro_elemento = lista[0]
print(primeiro_elemento)
# Out:
# [4, 9, 3]
# 12

# %%
tupla = (4, 9, 3)

print(tupla)

#tupla[0] = 12

primeiro_elemento = tupla[0]
print(primeiro_elemento)

tupla_unico_item = 4, 5, 6, 7
print(tupla_unico_item)
print(type(tupla_unico_item))
# Out:
# (4, 9, 3)
# 4
# (4, 5, 6, 7)
# <class 'tuple'>

# %%
dicionario = {
    'Estado': 'São Paulo',
    'Cidade': 'São Caetano'
}

print(dicionario)

print(dicionario['Estado'])
print(dicionario['Cidade'])
# Out:
# {'Estado': 'São Paulo', 'Cidade': 'São Caetano'}
# São Paulo
# São Caetano
